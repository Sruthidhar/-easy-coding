# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline
pd.set_option("display.float_format", lambda x: "%.2f" % x) #to display value

# %%
df= pd.read_csv(r"C:\Users\sruth\Downloads\Play_Store_2.csv")
df.head()
# Out:
#                      App             Category  Rating   Reviews   Size  \
# 0            War Dragons               Others    3.90 160604.00 270.00
# 1  CV-Library Job Search             BUSINESS    4.40       NaN  46.00
# 2        Surah Al-Waqiah  BOOKS_AND_REFERENCE     NaN   1201.00  29.00
# 3                     Ay               Others     NaN     11.00  36.00
# 4                EA Plus               Others    2.50     12.00  12.00
#
#      Installs Paid/Free  Price Content Rating Ad Supported In App Purchases  \
# 0 10000000.00      Free   0.00       Everyone          Yes              Yes
# 1   100000.00      Free   0.00       Everyone           No               No
# 2   100000.00      Free   0.00       Everyone          Yes               No
# 3     5000.00      Free   0.00           Teen          Yes               No
# 4     1000.00      Free   0.00       Everyone           No               No
#
#   Editors Choice
# 0            Yes
# 1             No
# 2             No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   App               4153 non-null   object
#  1   Category          4153 non-null   object
#  2   Rating            3976 non-null   float64
#  3   Reviews           4029 non-null   float64
#  4   Size              4153 non-null   float64
#  5   Installs          4153 non-null   float64
#  6   Paid/Free         4153 non-null   object
#  7   Price             4153 non-null   float64
#  8   Content Rating    4153 non-null   object
#  9   Ad Supported      4153 non-null   object
#  10  In App Purchases  4153 non-null   object
#  11  Editors Choice    4153 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 389.5+ KB

# %%
df.describe().T
# Out:
#            count       mean        std  min      25%       50%        75%  \
# Rating   3976.00       4.19       0.52 1.00     4.00      4.30       4.50
# Reviews  4029.00   66964.21  107418.85 1.00   224.00   7461.00   78219.00
# Size     4153.00      82.25      92.26 0.01    22.00     42.00      84.00
# Installs 4153.00 3232705.64 5421343.28 1.00 10000.00 500000.00 5000000.00
# Price    4153.00       0.57       8.93 0.00     0.00      0.00       0.00
#
#                  max
# Rating          5.00
# Reviews    312204.00
# Size          270.00
# Installs 19970000.00
# Price         399.99

# %%
# checking missing values
df.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating              177
# Reviews             124
# Size                  0
# Installs              0
# Paid/Free             0
# Price                 0
# Content Rating        0
# Ad Supported          0
# In App Purchases      0
# Editors Choice        0
# dtype: int64

# %%
df['Rating'] = df['Rating'].fillna(value= df['Rating'].mean())

# %%
df['Reviews'] = df['Reviews'].fillna(value= df['Reviews'].median())

# %%
df.isnull().sum()
# Out:
# App                 0
# Category            0
# Rating              0
# Reviews             0
# Size                0
# Installs            0
# Paid/Free           0
# Price               0
# Content Rating      0
# Ad Supported        0
# In App Purchases    0
# Editors Choice      0
# dtype: int64

# %%
#UNIVARIATE ANALYSIS

# %%
sns.histplot(data=df,x='Rating')
plt.show()
sns.boxplot(data=df,x='Rating')
plt.show()

# %%
sns.histplot(data=df,x='Reviews')
plt.show()
sns.boxplot(data=df,x='Reviews')
plt.show()

# %%
sns.histplot(data=df,x='Size')
plt.show()
sns.boxplot(data=df,x='Size')
plt.show()

# %%
sns.histplot(data=df,x='Installs')
plt.show()
sns.boxplot(data=df,x='Installs')
plt.show()

# %%
sns.histplot(data=df,x='Price')
plt.show()
sns.boxplot(data=df,x='Price')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df, x='Category')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='Paid/Free');

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='Content Rating');

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='Editors Choice');

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='Ad Supported');

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='In App Purchases');

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df[df['Paid/Free']=='Free'], x='In App Purchases');

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df[df['Paid/Free']=='Free'], x='Ad Supported');

# %%
# Bivariate Analysis

# %%
plt.figure(figsize=(15,8)) 
sns.boxplot(data=df, x='Category', y='Rating')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x='Category', y='Reviews', ci=False, estimator='sum')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x='Category', y='Installs', ci=False, estimator='sum')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x='Category', y='Price' , ci=False, estimator='sum')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,8))
sns.countplot(data= df[df['Paid/Free']=='Free'], x='Category', hue='Ad Supported')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df[df['Ad Supported']=='Yes'], x='Category', hue='Paid/Free')
plt.xticks(rotation=90);

# %%
sns.pairplot(data=df, diag_kind="kde")
plt.show();

# %%
corr = df.corr()
# plot the heatmap

plt.figure(figsize=(15, 7))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
# outlier detection using boxplot
# selecting the numerical columns of data and adding their names in a list 
numeric_columns = ['Rating', 'Reviews', 'Size', 'Installs','Price']
plt.figure(figsize=(15, 12))

for i, variable in enumerate(numeric_columns):
    plt.subplot(4, 4, i + 1)
    plt.boxplot(df[variable], whis=1.5)
    plt.tight_layout()
    plt.title(variable)

plt.show()

# %%
#Conclusions
The Dataset extracted from the Google Play store has been analysed to understand the trend of categories which can be beneficial for investors. With the help of descriptive analysis and visualisations, some insights have been drawn as below:

There are a total of 16 categories, among which apps under the Others category are maximum. Since these apps are a mixture of different categories, it will be difficult to conclude which type of app is trending. However, we can look for the second-best category i.e. Family category which has the most number of apps
This category of apps is also trending as apps that are free to use and also support Ads
There is a significant difference for free apps between apps that support Ads or not
Almost 80% of apps are rated for all Age groups of users
Ratings for apps does not show any significant effect based on categorization of apps
Higher the number of reviews, higher will be the installation of those apps
Apps under Family category being costlier than other categories still manages to get good ratings, an optimum number of Reviews and installations
It can be inferred that apps under category Family are trending along with some other categories like Game, Tools etc.
Recommendations
Agency should focus on apps under Family category for Advertisement as they are significantly trending in the market. They can invest in other categories like Game and Tools as they also contain trending apps
Since apps which support Ads are mostly free to use, Agency should look forward to invest in free apps rather than paid apps
Investing in free apps under category like Finance, Medical, should be avoided as they do not support advertisements
As there is a high correlation between Reviews and Installations, therefore agency should check for those apps which have high number of reviews as those apps are more likely to get installed
Agency should not invest in apps under category Business, Books and References as they are not preferred by the users as they have very low number of installations even they are free to use
# Out:
#   Input In [37]
#     The Dataset extracted from the Google Play store has been analysed to understand the trend of categories which can be beneficial for investors. With the help of descriptive analysis and visualisations, some insights have been drawn as below:
#         ^
# SyntaxError: invalid syntax
